# %%
import numpy as py
import pandas as pd

# %%
samsung = pd.read_csv("C:/Users/ysh/Downloads/project_dongguk/crawling/samsung_disease.csv")

# %%
naver = pd.read_csv("C:/Users/ysh/Downloads/project_dongguk/crawling/naver_disease.csv")

# %%
samsung
# Out:
#            title        subject  \
# 0           수족구병         소아청소년과
# 1     중증열성혈소판감소증           감염내과
# 2     지카바이러스 감염증           감염내과
# 3        성전파성 질환     비뇨의학과,산부인과
# 4           뇌수막염     신경과,소아청소년과
# ..           ...            ...
# 570  선천성 낭종성 폐질환   소아청소년과,호흡기내과
# 571        디프테리아           감염내과
# 572      다제내성 결핵     호흡기내과,감염내과
# 573           비만          가정의학과
# 574      만성피로증후군  정신건강의학과,가정의학과
#
#                                             definition  \
# 0    손, 발, 입에 장바이러스의 일종인 콕사키 A 바이러스나 엔테로바이러스 71의 감염...
# 1    중증열성혈소판감소증후군 바이러스에 감염된 진드기에 물려 감염되며 고열과 혈소판 감소...
# 2                지카바이러스(Zika virus) 감염에 의한 급성 감염질환입니다.
# 3    성병은 주로 사람과 사람사이에 성 접촉으로 전파되는 질환입니다. 흔한 성병으로는 임...
# 4    뇌수막염이란 뇌조직을 둘러싸고 있는 얇은 막과 뇌 사이에 염증이 생기는 것을 의미합니다.
# ..                                                 ...
# 570  선천성 낭종성 폐질환은 태아의 폐 발육 과정 중에 발생하는 결함으로 생기는 질환으로...
# 571  디프테리아는 주로 코와 목의 점막이나 피부에 영향을 미치는 심각한 박테리아 감염입니...
# 572  다제내성 결핵(Multi-Drug Resistant tuberculosis)이란 넓...
# ...

# %%
naver
# Out:
#            title                        subject  \
# 0     내측 측부인대 파열                           정형외과
# 1       장경인대 증후군                           정형외과
# 2         슬개골 탈구                           정형외과
# 3        화농성 관절염                           정형외과
# 4            혈관종                           성형외과
# ...          ...                            ...
# 1072     노로 바이러스              감염내과,소화기내과,소아청소년과
# 1073         한센병                       감염내과,피부과
# 1074         광견병                       감염내과,신경과
# 1075          감기  가정의학과,감염내과,호흡기내과,소아청소년과,이비인후과
# 1076        간흡충증                     감염내과,소화기내과
#
#                                              definition  \
# 0     내측측부인대 손상은 슬관절에 과도한 외반력이 가해질 때 생기는 것으로 단독 손상으로...
# 1     장경인대는 운동 선수들이 흔히 통증을 호소하는 부위로 무릎 장경인대와 대퇴 외과 사...
# 2     슬개골은 대퇴골과 접촉하며 관절면을 이루는데 여러 가지 원인에 의해 대퇴골에서 탈구...
# 3     감염성관절염이라고도 알려진 화농성 관절염은 염증을 일으키는 감염원이 관절내에 들어옴...
# 4     발생 단계에 있는 미분화한 모세혈관그물이 정상 혈관으로 발전하지 못해서 생긴 것을 ...
# ...

# %%
total_disease = pd.concat([naver, samsung], ignore_index=True)

# %%
total_disease
# Out:
#             title        subject  \
# 0      내측 측부인대 파열           정형외과
# 1        장경인대 증후군           정형외과
# 2          슬개골 탈구           정형외과
# 3         화농성 관절염           정형외과
# 4             혈관종           성형외과
# ...           ...            ...
# 1647  선천성 낭종성 폐질환   소아청소년과,호흡기내과
# 1648        디프테리아           감염내과
# 1649      다제내성 결핵     호흡기내과,감염내과
# 1650           비만          가정의학과
# 1651      만성피로증후군  정신건강의학과,가정의학과
#
#                                              definition  \
# 0     내측측부인대 손상은 슬관절에 과도한 외반력이 가해질 때 생기는 것으로 단독 손상으로...
# 1     장경인대는 운동 선수들이 흔히 통증을 호소하는 부위로 무릎 장경인대와 대퇴 외과 사...
# 2     슬개골은 대퇴골과 접촉하며 관절면을 이루는데 여러 가지 원인에 의해 대퇴골에서 탈구...
# 3     감염성관절염이라고도 알려진 화농성 관절염은 염증을 일으키는 감염원이 관절내에 들어옴...
# 4     발생 단계에 있는 미분화한 모세혈관그물이 정상 혈관으로 발전하지 못해서 생긴 것을 ...
# ...                                                 ...
# 1647  선천성 낭종성 폐질환은 태아의 폐 발육 과정 중에 발생하는 결함으로 생기는 질환으로...
# 1648  디프테리아는 주로 코와 목의 점막이나 피부에 영향을 미치는 심각한 박테리아 감염입니...
# ...

# %%
total_disease.to_csv('total_disease2.csv', index=False, mode='a', encoding='utf-8-sig', )
